# %%
import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup
from pykml import parser
import re
import pgeocode
from geopy.geocoders import Nominatim

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
with open('Worldwide_Board_Game_Cafe_List.kml','r') as f:
    doc = parser.parse(f).getroot()

# %%
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_Europe'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'lxml')
table = soup.find_all('table', attrs={'class':'wikitable'})[1]
eu_countries = [td.a.text for td in table.find_all('td')[2::7]]

# %%
eu_countries.remove('United Kingdom')
eu_countries.extend(['England', 'Scotland', 'Wales', 'Northern Ireland'])
eu_countries.sort()

# %%
eu_countries
# Out:
# ['Albania',
#  'Andorra',
#  'Armenia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'England',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Kazakhstan',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Moldova',
#  'Monaco',
#  'Montenegro',
#  'Netherlands',
#  'North Macedonia',
#  'Northern Ireland',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'San Marino',
#  'Scotland',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'Ukraine',
#  'Vatican City',
#  'Wales']

# %%
cafe_list = []

# %%
for e in doc.Document.findall('.//{http://www.opengis.net/kml/2.2}Placemark'):
    cafe_dict = dict()
    if e.ExtendedData.Data[5].value in eu_countries:
        cafe_dict = { 
            'Name': e.name.text,
            'Address': e.ExtendedData.Data[1].value.text,
            'City': e.ExtendedData.Data[2].value.text,
            'PostalCode': e.ExtendedData.Data[4].value.text,
            'Country': e.ExtendedData.Data[5].value.text
                    }
        cafe_list.append(cafe_dict)

# %%
for item in cafe_list:
    if item['Country'] == 'Czech Republic':
        item['Country'] = 'Czechia'

# %%
cafe_df = pd.DataFrame(cafe_list)
cafe_df.head(10)
# Out:
#                          Name                Address       City PostalCode  \
# 0               Brot & Spiele   Mariahilferstraße 17       Graz       8020
# 1             Brot und Spiele         Laudongasse 22     Vienna       1080
# 2                  Café Benno          Alser Str. 67     Vienna       1080
# 3               Café Sperlhof    Große Sperlgasse 41     Vienna       1020
# 4                    SpielBar        Lederergasse 26     Vienna       1080
# 5  The Playground (Hoofdkerk)      Hoofdkerkstraat 7    Antwerp       2000
# 6    The Playground (Station)  Pelikaanstraat 3/1270    Antwerp       2018
# 7           Outpost Antwerpen    Beggaardenstraat 6   Antwerpen       2000
# 8              The Playground      Hoofdkerkstraat 7  Antwerpen       2000
# 9            La Luck Brussels      74 rue Washington   Brussels       1050
#
#    Country
# 0  Austria
# 1  Austria
# 2  Austria
# 3  Austria
# 4  Austria
# 5  Belgium
# 6  Belgium
# 7  Belgium
# 8  Belgium
# 9  Belgium

# %%
gn_url = 'http://www.geonames.org/countries/'
gn_response = requests.get(gn_url)
gn_soup = BeautifulSoup(gn_response.content, 'lxml')

# %%
gn_table = gn_soup.find_all('tr')[2:]
code_list = []
for tr in gn_table:
    code_dict = dict()
    td = tr.find_all('td')
    if td[-1].text in ['EU', 'AS']: # We include AS because GeoNames includes Turkey within Asia
        code_dict = {
            'Country': td[4].text,
            'Code': td[0].text
                    }
        code_list.append(code_dict)

# %%
code_df = pd.DataFrame(code_list)

# %%
uk_countries = [{'Country': 'England', 'Code': 'GB'}, 
                {'Country': 'Scotland', 'Code': 'GB'}, 
                {'Country': 'Wales', 'Code': 'GB'}, 
                {'Country': 'Northern Ireland', 'Code': 'GB'}]

# %%
code_df = pd.concat([code_df, pd.DataFrame(uk_countries)])
code_df.set_index('Country', inplace=True)
code_df.drop('United Kingdom', axis=0, inplace=True)
code_df.sort_index()
# Out:
#                                Code
# Country
# Afghanistan                      AF
# Albania                          AL
# Andorra                          AD
# Armenia                          AM
# Austria                          AT
# Azerbaijan                       AZ
# Bahrain                          BH
# Bangladesh                       BD
# Belarus                          BY
# Belgium                          BE
# Bhutan                           BT
# Bosnia and Herzegovina           BA
# British Indian Ocean Territory   IO
# Brunei                           BN
# Bulgaria                         BG
# Cambodia                         KH
# China                            CN
# Cocos [Keeling] Islands          CC
# Croatia                          HR
# Cyprus                           CY
# Czechia                          CZ
# Denmark                          DK
# England                          GB
# Estonia                          EE
# Faroe Islands                    FO
# Finland                          FI
# France                           FR
# Georgia                          GE
# Germany                          DE
# Gibraltar                        GI
# Greece                           GR
# Guernsey                         GG
# Hong Kong                        HK
# Hungary                          HU
# Iceland                          IS
# India                            IN
# Indonesia                        ID
# Iran                             IR
# Iraq                             IQ
# Ireland                          IE
# Isle of Man                      IM
# Israel                           IL
# Italy                            IT
# Japan                            JP
# Jersey                           JE
# Jordan                           JO
# Kazakhstan                       KZ
# Kosovo                           XK
# Kuwait                           KW
# Kyrgyzstan                       KG
# Laos                             LA
# Latvia                           LV
# Lebanon                          LB
# Liechtenstein                    LI
# Lithuania                        LT
# Luxembourg                       LU
# Macao                            MO
# Malaysia                         MY
# Maldives                         MV
# Malta                            MT
# Moldova                          MD
# Monaco                           MC
# Mongolia                         MN
# Montenegro                       ME
# Myanmar                          MM
# Nepal                            NP
# Netherlands                      NL
# North Korea                      KP
# North Macedonia                  MK
# Northern Ireland                 GB
# Norway                           NO
# Oman                             OM
# Pakistan                         PK
# Palestine                        PS
# Philippines                      PH
# Poland                           PL
# Portugal                         PT
# Qatar                            QA
# Romania                          RO
# Russia                           RU
# San Marino                       SM
# Saudi Arabia                     SA
# Scotland                         GB
# Serbia                           RS
# Serbia and Montenegro            CS
# Singapore                        SG
# Slovakia                         SK
# Slovenia                         SI
# South Korea                      KR
# Spain                            ES
# Sri Lanka                        LK
# Svalbard and Jan Mayen           SJ
# Sweden                           SE
# Switzerland                      CH
# Syria                            SY
# Taiwan                           TW
# Tajikistan                       TJ
# Thailand                         TH
# Turkey                           TR
# Turkmenistan                     TM
# Ukraine                          UA
# United Arab Emirates             AE
# Uzbekistan                       UZ
# Vatican City                     VA
# Vietnam                          VN
# Wales                            GB
# Yemen                            YE
# Åland                            AX

# %%
cafe_df = cafe_df.merge(code_df, how='left', on='Country')
cafe_df.head(10)
# Out:
#                          Name                Address       City PostalCode  \
# 0               Brot & Spiele   Mariahilferstraße 17       Graz       8020
# 1             Brot und Spiele         Laudongasse 22     Vienna       1080
# 2                  Café Benno          Alser Str. 67     Vienna       1080
# 3               Café Sperlhof    Große Sperlgasse 41     Vienna       1020
# 4                    SpielBar        Lederergasse 26     Vienna       1080
# 5  The Playground (Hoofdkerk)      Hoofdkerkstraat 7    Antwerp       2000
# 6    The Playground (Station)  Pelikaanstraat 3/1270    Antwerp       2018
# 7           Outpost Antwerpen    Beggaardenstraat 6   Antwerpen       2000
# 8              The Playground      Hoofdkerkstraat 7  Antwerpen       2000
# 9            La Luck Brussels      74 rue Washington   Brussels       1050
#
#    Country Code
# 0  Austria   AT
# 1  Austria   AT
# 2  Austria   AT
# 3  Austria   AT
# 4  Austria   AT
# 5  Belgium   BE
# 6  Belgium   BE
# 7  Belgium   BE
# 8  Belgium   BE
# 9  Belgium   BE

# %%
def get_coords(row):
    geo = pgeocode.Nominatim(row[-1])
    coords = geo.query_postal_code(row[3])
    return [coords.latitude, coords.longitude]

# %%
coord_list = []

# %%
for row in cafe_df.values:
    coord_dict = dict()
    try:
        ll = get_coords(row)
    except:
        ll = [np.nan, np.nan]
    coord_dict = {
        'Latitude': ll[0], 
        'Longitude': ll[1]         
                 }
    coord_list.append(coord_dict)

# %%
coord_df = pd.DataFrame(coord_list)
coord_df.head(10)
# Out:
#    Latitude  Longitude
# 0   47.0232    15.5337
# 1   48.2167    16.3500
# 2   48.2167    16.3500
# 3   48.2167    16.4000
# 4   48.2167    16.3500
# 5   51.2199     4.4035
# 6   51.2199     4.4035
# 7   51.2199     4.4035
# 8   51.2199     4.4035
# 9   50.8333     4.3667

# %% [markdown]
# Let's check to see if there are any cafés that could not provide coordinates.

# %%
null_idx = coord_df.index[coord_df['Latitude'].isnull()].tolist()
null_cafes = cafe_df.iloc[null_idx]
null_cafes
# Out:
#                          Name  \
# 23                   3 Trolls
# 42            The Games Table
# 73                Dice Saloon
# 124            Game of trolls
# 192                 Playhouse
# 193               Κάισσα Cafe
# 194                    Playce
# 195                 Playhouse
# 196                 Playhouse
# 197                 Playhouse
# 198          This HOUSE RULES
# 199                 Playhouse
# 200              Back 2 Games
# 201         Harry's Spot Cafe
# 202                 Playhouse
# 211                  Tabletop
# 220                  Counters
# 223           Brainstorm Cafe
# 224    Spellencentrum Agartha
# 225                2 Klaveren
# 226          Friends and Foes
# 227            Escaping Breda
# 228                   Barbaar
# 229               Bordspelers
# 231             The Boardroom
# 232               Spellenhuis
# 275                     Astal
# 276             Gaming Centar
# 286               Café Sirius
# 291  Da Vinci Board Game Cafe
#
#                                                Address          City  \
# 23                                  ul. "Oborishte" 80         Sofia
# 42                            86 Magdalen St, Norwich       Norwich
# 73   Unit 6, Longley Industrial Estate, New England...      Brighton
# 124                                     8 rue de Paris       Moulins
# 192                                      Valtetsiou 49        Athens
# 193                          Μεσογείων 12, Αμπελόκηποι        Athens
# 194                              Vasili Logothetidi 14        Athina
# 195                                     Sakellariou 21      Ioannina
# 196                                         Poulidou 6        Kavala
# 197                                       Panagouli 16        Larisa
# 198                                       Dim. Ralli 4       Marousi
# 199                                    Riga Fereou 127         Patra
# 200                                Geor. Papandreou 27  Thessaloniki
# 201                                         Aggelaki 8  Thessaloniki
# 202                                Vasilissis Sofias 5        Xanthi
# 211                                    9 Castle Street          Cork
# 220                       Pontypridd YMCA, Taff Street    Pontypridd
# 223                            Alexander Pushkin St 52      Chisinau
# 224                                   Legmeerdijk 169a      Aalsmeer
# 225                                De Clercqstraat 136     Amsterdam
# 226                                Van Woustraat 202-A     Amsterdam
# 227                              Boschstraat 112 -116,         Breda
# 228                                 Sint Agathaplein 4         Delft
# 229                               Lange Groenendaal 82         Gouda
# 231                                     Kruisweg 60-62       Haarlem
# 232                                    Torenstraat 142     The Hague
# 275                                   27 Kralja Milana      Belgrade
# 276                            Trg Marije Trandafil 14      Novi Sad
# 286                                      Kungsgatan 19      Göteborg
# 291                           Kazakistan Cd. 69-71 D:A        Ankara
#
#          PostalCode      Country Code
# 23   1505 Oborishte     Bulgaria   BG
# 42          NR311JF      England   GB
# 73           BN14GY      England   GB
# 124            3000       France   FR
# 192          106 81       Greece   GR
# 193           11527       Greece   GR
# 194          115 24       Greece   GR
# 195          453 33       Greece   GR
# 196          652 01       Greece   GR
# 197          412 22       Greece   GR
# 198          151 24       Greece   GR
# 199          262 21       Greece   GR
# 200           54645       Greece   GR
# 201           54621       Greece   GR
# 202          671 00       Greece   GR
# 211             021      Ireland   IE
# 220        CF37 4TR        Italy   IT
# 223            0000      Moldova   MD
# 224         1432 KA  Netherlands   NL
# 225         1052 NP  Netherlands   NL
# 226         1073 NA  Netherlands   NL
# 227         4811 GK  Netherlands   NL
# 228         2611 HR  Netherlands   NL
# 229         2801 LV  Netherlands   NL
# 231          2011LE  Netherlands   NL
# 232         2513 BW  Netherlands   NL
# 275           11000       Serbia   RS
# 276           21000       Serbia   RS
# 286           41119       Sweden   SE
# 291            6490       Turkey   TR

# %% [markdown]
# Well, that's a number of missing data pieces. On a hunch, let's first count the number of cafés per country in both `cafe_df` and `null_cafes`.

# %%
cafe_df.groupby('Country').count()
# Out:
#                   Name  City  PostalCode  Code
# Country
# Austria              5     5           5     5
# Belgium             15    15          15    15
# Bulgaria             4     4           4     4
# Czechia              3     3           3     3
# Denmark             11    11          11    11
# England             78    78          78    78
# Finland              2     2           2     2
# France              57    57          57    57
# Germany             17    17          17    17
# Greece              11    11          11    11
# Hungary              7     7           7     7
# Iceland              1     1           1     1
# Ireland              5     5           5     5
# Italy                7     7           7     7
# Moldova              1     1           1     1
# Netherlands          9     9           9     9
# North Macedonia      1     1           1     1
# Northern Ireland     2     2           2     2
# Norway               2     2           2     2
# Poland              10    10          10    10
# Portugal             3     3           3     3
# Romania              7     7           7     7
# Scotland            17    17          17    17
# Serbia               2     2           2     2
# Slovenia             1     1           1     1
# Spain                8     8           8     8
# Sweden               2     2           2     2
# Switzerland          3     3           3     3
# Turkey               2     2           2     2
# Wales                2     2           2     2

# %%
null_cafes.groupby('Country').count()
# Out:
#              Name  City  PostalCode  Code
# Country
# Bulgaria        1     1           1     1
# England         2     2           2     2
# France          1     1           1     1
# Greece         11    11          11    11
# Ireland         1     1           1     1
# Italy           1     1           1     1
# Moldova         1     1           1     1
# Netherlands     8     8           8     8
# Serbia          2     2           2     2
# Sweden          1     1           1     1
# Turkey          1     1           1     1

# %% [markdown]
# By comparing these numbers, we can see that every café in Greece, Moldova and Serbia are missing, which suggests that `pgeocode` does not contain information for these countries (and a check of the [github page](https://github.com/symerio/pgeocode) for `pgeocode` confirms this). This will require utilising a different source for the information.
# Otherwise, the postal codes for the remaining entries of `null_cafes` must contain errors and need to be manually changed.

# %% [markdown]
# So, what is next to sort out is a) making sure we can obtain the coordinates for Greece, Moldova and Serbia (and Netherlands)~~; and b) remove any duplicate entries within `cafe_df`~~.

# %% [markdown]
# Starting with the duplicates...
#
# (In addition, we need to change the city names to match---e.g. issues within Belgium such as Antwerpen vs. Antwerp and Bruxelles and Brussels---in order to later group things by city.)

# %%
cafe_df
# Out:
#                                              Name  \
# 0                                   Brot & Spiele
# 1                                 Brot und Spiele
# 2                                      Café Benno
# 3                                   Café Sperlhof
# 4                                        SpielBar
# 5                      The Playground (Hoofdkerk)
# 6                        The Playground (Station)
# 7                               Outpost Antwerpen
# 8                                  The Playground
# 9                                La Luck Brussels
# 10                          La Table Food & Games
# 11                               Outpost Brussels
# 12                               Kings and Queens
# 13                             OutPost Gamecenter
# 14              World's End Comics & Games Center
# 15                                        Oberonn
# 16                                       Yam-toto
# 17                         Aux 3D Board Game Cafe
# 18                                Brood en Spelen
# 19                                        De Ezel
# 20                                  Meeple People
# 21                                   Offline Café
# 22                                BoardGames Ruse
# 24                              Mystica TEA & PUB
# 25                            A Maze in Tchaiovna
# 26                         Bohemia Boards & Brews
# 27                          Aalborg Brætspilscafé
# 28                                 Dice 'n Drinks
# 29                Aarhus Brtspilscafe Fredensgade
# 30                 Aarhus Brtspilscafe Vestergade
# 31                                   Bastard Cafe
# 32                  Social Corner Board Game Cafe
# 33                               The Bastard Cafe
# 34                                        Topdeck
# 35                                   Cafe Firefly
# 36                                   Papas Papbar
# 37                                         Æ Bræt
# 38                             Ready Steady Roll
# 39                          Counter Culture Games
# 40                Slice and Dice (monthly pop up)
# 41                           Zatu Board Game Café
# 42                                The Games Table
# 43                              Ready Steady Roll
# 44                             Ready, Steady Roll
# 45                            d20 Board Game Cafe
# 46                                    Bean Gaming
# 47                                          Quest
# 48                          Red Panda Gaming Cafe
# 49                        Geek Retreat Nottingham
# 50                                   Ludorati BGC
# 51                                  Ludorati Café
# 52                                   The Dice Cup
# 53                      Ludoquist Board Game Cafe
# 54                                  Bad Moon Cafe
# 55           Draughts - Board Game Café - Hackney
# 56          Draughts - Board Game Café - Waterloo
# 57                                The Library Pot
# 58                            Loading Bar Dalston
# 59                                       tea@HART
# 60                                  Fire and Dice
# 61                                    Meeple Perk
# 62                         Geek Retreat Newcastle
# 63                                    Cherry Moon
# 64                                   Slice & Dice
# 65                        Critical Hit Games Cafe
# 66                                 Sugar and Dice
# 67                                     Tiny Ricks
# 68                                  Fan Boy Three
# 69                                    Board Beans
# 70                            Geek Retreat Wirral
# 71                                 The Gaming Den
# 72                                 c:\ Side Quest
# 73                                    Dice Saloon
# 74                                    Dice Saloon
# 75                           Loading Bar Brighton
# 76                                   Paradice BGC
# 77                          Comics Games & Coffee
# 78                                 Dice & a Slice
# 79                               Dice and a Slice
# 80                               The Mug & Meeple
# 81                                  Unplug & Play
# 82                            TRINITY Gaming cafe
# 83                                     Digi Diner
# 84                     Geek Retreat Milton Keynes
# 85                               Players Paradice
# 86                                           Dice
# 87                                     Playopolis
# 88                          Board in the City CIC
# 89                          Comics Games & Coffee
# 90                                Thirsty Meeples
# 91                              Chance & Counters
# 92                  Replay Bristol Board Game Bar
# 93                                          Board
# 94                                 Dice & a Slice
# 95                                          Twist
# 96                              Chance & Counters
# 97                        Geek Retreat Birmingham
# 98                                  Meeple Mayhem
# 99                                 Sliced N Diced
# 100                Snax & Ladders Board Game Cafe
# 101                                  Dice Box BGC
# 102                                The Dell House
# 103                                      Manaflux
# 104        Nerdy Coffee Company in Shrewsbury, UK
# 105                                        Arcane
# 106                         Geek Retreat Bradford
# 107                           Bake, Battle & Roll
# 108                                     IQ Gaming
# 109                           The People's Meeple
# 110                                The Board Room
# 111                            Geek Retreat Leeds
# 112                                TAU Gaming Ltd
# 113                 The Treehouse Board Game Cafe
# 114                              Random Encounter
# 115  RanSacked Board Game Lounge and Escape Rooms
# 116                                Cafe Boardgame
# 117                      Lautapelikahvila Taverna
# 118                Baraka Jeux - Clermont-Ferrand
# 119                          La Tete dans le Pion
# 120                                    Archi-Jeux
# 121                                K fee des jeux
# 122                                       Barnade
# 123                    Moi j'm'en fous, je triche
# 124                                Game of trolls
# 125                                     Shrubbery
# 126                                  Le De Masque
# 127                       Auberge des VoyaJoueurs
# 128                L'Heure du Jeu - Champs Libres
# 129                                  Bonne Pioche
# 130                  L'Aliane, Café Boutiquo-Jeux
# 131                           La Feinte de l'Ours
# 132                                       Dé Zinc
# 133                                   Baraka Jeux
# 134                    Les Tricheurs - Bar à jeux
# 135                                      Philibar
# 136                               Schluck N'Spiel
# 137                                 Aux Dés Calés
# 138                                   Café Meisia
# 139                                      Café Oya
# 140          Le Dernier Bar avant la Fin du Monde
# 141                          Le Nid Cocon Ludique
# 142                                      Loufoque
# 143                                   Meeple Café
# 144                                 The Good Game
# 145                            La Tartine Ludique
# 146      Le QG des Avenjoueurs Bar à Jeux à Rouen
# 147                                    Cup n'dice
# 148                               Le Gros Corbeau
# 149                                       El Joko
# 150                                    Jeux Barjo
# 151                                  La Muse Café
# 152                                  L'Antre Jeux
# 153                                  Laluditavern
# 154                     Baraka Jeux - Montpellier
# 155                                  Game Taverne
# 156                                   Les Castors
# 157                                   Baraka Jeux
# 158                                    BlastoDice
# 159                           La Taverne du Troll
# 160                   Les Tricheurs - Bar ludique
# 161                                     Yggdrasil
# 162                      Le Warp, Taverne Ludique
# 163                              La Fabrik a Jeux
# 164                   Sur un plateau - Bar à jeux
# 165         PlatÔbar Bar à Jeux à Aix en Provence
# 166                   Au Café des Meeples Avignon
# 167                                     Le Barjoc
# 168                       Baraka Jeux - Marseille
# 169                                La Case Depart
# 170                             Café Jeux Natema.
# 171                                   La Revanche
# 172                           Les Mauvais Joueurs
# 173                           La malle d'Apolline
# 174                                     EPISODE 0
# 175              Brettspielplatz - Das Spielecafé
# 176                                 Interface Bar
# 177                             Spiele-Wirtschaft
# 178                             Spielwiese Berlin
# 179                 Gaststätte Zu den vier Winden
# 180                  Voyager - Boardgame Bar Bonn
# 181                                 Gastspielhaus
# 182                                       Barneby
# 183                                 White Rabbit
# 184                                Spielezeitcafe
# 185                                     FreiSpiel
# 186                 Spielcafe Deichhaus Game Café
# 187                               Wurfel & Zucker
# 188          Rollen - und Brettspielverein Thoule
# 189             ZAMgwurfelt - the board game cafe
# 190                           Spielcafé Osnabrett
# 191                   Spielecafé der Generationen
# 192                                     Playhouse
# 193                                   Κάισσα Cafe
# 194                                        Playce
# 195                                     Playhouse
# 196                                     Playhouse
# 197                                     Playhouse
# 198                              This HOUSE RULES
# 199                                     Playhouse
# 200                                  Back 2 Games
# 201                             Harry's Spot Cafe
# 202                                     Playhouse
# 203                                 BarCraft Buda
# 204                              BarCraft Nyugati
# 205                      Board Game Cafe Budapest
# 206                                  Game Up Cafe
# 207                                   Game Up Pub
# 208                            Vault 51 Gamer Bar
# 209                             BarCraft Debrecen
# 210                                    Spilavinir
# 211                                      Tabletop
# 212                                 Tabletop Cork
# 213                            The Clockwork Door
# 214                               The Square Ball
# 215                    Dungeons and Donuts Galway
# 216                          Il Respiro del Drago
# 217                            La città del gioco
# 218                                   Ludos libra
# 219                                   Goblin Café
# 221              Go to Play Board Game Bar & Cafe
# 222                         Jolly Joker Game Cafe
# 223                               Brainstorm Cafe
# 224                        Spellencentrum Agartha
# 225                                    2 Klaveren
# 226                              Friends and Foes
# 227                                Escaping Breda
# 228                                       Barbaar
# 229                                   Bordspelers
# 230                                Purperen Draak
# 231                                 The Boardroom
# 232                                   Spellenhuis
# 233                          Board Game Cafe Samo
# 234                                   Jack Straws
# 235                             Robins Hobby Cafe
# 236                               Grimfield Games
# 237                                     Work Work
# 238                                    Graciarnia
# 239                                    Ludiversum
# 240                                      Boardowa
# 241                                           Hex
# 242            K6 Pub - Planszówki & Cocktail Bar
# 243                                    Pub Goblin
# 244                                  Kawadziescia
# 245                                  Paradox Cafe
# 246                                        AR-Bar
# 247                                           Hex
# 248                       Ludoclube - Abre o Jogo
# 249                      Pow Wow Games and Drinks
# 250                    AJogar Équeagenteseentende
# 251                         Creative Board Gaming
# 252                                Snakes&Wizards
# 253                                The Guild Hall
# 254                             Harmony Cafe Iași
# 255                                    Retro Cafe
# 256                   FatCats Board Game Cafe Bar
# 257                                 Le & Le Games
# 258                                       Unboxed
# 259                          Games Hub Edinburgh
# 260                        Geek Retreat Edinburgh
# 261           Noughts and Coffees Board Game Café
# 262                                Dice Roll Café
# 263                          Geek Retreat Glasgow
# 264                                 Lucky Sparrow
# 265                      Lucky Sparrow Games Cafe
# 266                                 Max XP Gaming
# 267                               The Flying Duck
# 268                                West End Games
# 269                                      Settlers
# 270                       Geek Retreat Motherwell
# 271                                     Comicrazy
# 272                                Comicrazy Cafe
# 273                                 Big Dog Books
# 274                                 Common Ground
# 275                                         Astal
# 276                                 Gaming Centar
# 277                                  Dobra Poteza
# 278                                   Kaburi Cafe
# 279                          Continental Cafe Pub
# 280                                      La Pifia
# 281                          Epic Board Game Cafe
# 282                                     Comejuega
# 283                      Play Planet Coffe & Shop
# 284                                  GTS Mallorca
# 285                               Bruixes i Fades
# 286                                   Café Sirius
# 287                               Dice Cafe STHLM
# 288                                       ManaBar
# 289                                   Well Played
# 290                                    DuBischDra
# 291                      Da Vinci Board Game Cafe
# 292                              Goblin Oyun Cafe
# 293                             Chance & Counters
# 294                          Board, Isle of Wight
#
#                                                Address  \
# 0                                 Mariahilferstraße 17
# 1                                       Laudongasse 22
# 2                                        Alser Str. 67
# 3                                  Große Sperlgasse 41
# 4                                      Lederergasse 26
# 5                                    Hoofdkerkstraat 7
# 6                                Pelikaanstraat 3/1270
# 7                                  Beggaardenstraat 6
# 8                                    Hoofdkerkstraat 7
# 9                                    74 rue Washington
# 10                            63 rue de l'enseignement
# 11                                 Rue de la Tribune 8
# 12                           Rue du Fossé aux Loups 27
# 13                              Ottergemsesteenweg 13
# 14                                        Ketelvest 51
# 15                             Kempische steenweg 27/1
# 16                                  En Hors-Chateau 43
# 17                               Place Abbe Joseph, 11
# 18                                   Stationsstraat 41
# 19                                          Piepelpoel
# 20                   Bul. Tsar Boris III Obedinitel 52
# 21                                  Danail Nikolaev 39
# 22                                      ул. Борисова 8
# 24                                  Palackého třída 78
# 25                                           Muchova 4
# 26                                       Charkovská 18
# 27                                        Vesterbro 30
# 28                                  Sankelmarksgade 15
# 29                                      Fredensgade 38
# 30                                      Vestergade 58A
# 31                                     Rådhusstræde 13
# 32                                       Fiolstræde 25
# 33                                     Rådhusstræde 13
# 34                                    Carlsbergvej 32B
# 35                                         Munkegade 4
# 36                           Skt. Knuds Kirkestræde 2A
# 37                                Store Rådhusgade 19C
# 38                                          Ivy Lodge
# 39                                      26 Baddow Road
# 40                               7-9 Fye Bridge Street
# 41                           Bowthorpe Shopping Centre
# 42                            86 Magdalen St, Norwich
# 43                          Ivy Lodge, A6 Rushden Road
# 44           Studio 5, Ivy Lodge Farm, A6 Rushden Road
# 45                                      87 Queens Road
# 46                                    22 Silver Street
# 47                                   45 Belvoir Street
# 48                        247 High Street, First floor
# 49                                 7 Flying Horse Walk
# 50                                  72 Maid Marian Way
# 51                                  72 Maid Marian Way
# 52                                  68-70 Mansfield Rd
# 53                                 63 - 67 High Street
# 54                                 159a Great Dover St
# 55                                41 Kingsland High St
# 56                                   Arch 16, Leake St
# 234                     697-703 Upper Newtownards Road
# 235                                  145 Holywood Road
# 236                                       Storgaten 90
# 237                                       Munkegata 58
# 238                                  ul. Dmowskiego 15
# 239                                   ul. Kamienna 7/1
# 240                                        Topolowa 52
# 241                                     Dwernickiego 5
# 242                                    Piotrkowska 6/4
# 243                                       Wschodnia 74
# 244                         Tadeusza Krepowieckiego 10
# 245                                      Anielewicza 2
# 246                                            Rynek 5
# 247                                      Dubois 33/35b
# 248                              Av. Padre Himalaia 39
# 249            Rua Professor Fernando da Fonseca 19 22
# 250                      Rua Joaquim Maria de Melo 244
# 251                                   25 George Enescu
# 252                             5 Ilarie Chendi Street
# 253                                      Samuil Micu 4
# 254                                 Bulevardul Carol 1
# 255                         Str. Lascăr Catargi, nr.50
# 256                     Str. Principatele Unite, nr. 5
# 257                                   str. Artei nr. 3
# 258                         33-35 South Harbour Street
# 259                               101 Lauriston Place
# 260                                 30 Nicolson Square
# 261                                 26 Morrison Street
# 262                             350 Sauchiehall Street
# 263                                    63 Union Street
# 264                              1091 Pollokshaws Road
# 265                              1091 Pollokshaws Road
# 266                                  29-31 Duke Street
# 267                                142 Renfield Street
# 268                                  18 Woodlands Road
# 269                                   40 Castle Street
# 270                             54 Brandon Parade East
# 271                              45 Old Sneddon Street
# 272                                  45 Old Sneddon St
# 273                                    66 Scott Street
# 274                                      40B Cowane St
# 275                                   27 Kralja Milana
# 276                            Trg Marije Trandafil 14
# 277                                         Zelezna 14
# 278                           Passeig de Sant Joan, 11
# 279                                   C/ Seminario, 11
# 280              C/ Hospitalers de Sant Joan n.2 bajos
# 281                                 Calle Los Vascos 3
# 282                            Av. de Manuel Torres, 5
# 283                        Calle San Lorenzo Street 18
# 284                       Carrer Rosselló i Caçador, 7
# 285                          Carrer de Rubén Darío, 18
# 286                                      Kungsgatan 19
# 287                                    Polhemsgatan 21
# 288                             Schützenmattstrasse 31
# 289                                  Bahnhofstrasse 57
# 290                                      Geerenweg 23B
# 291                           Kazakistan Cd. 69-71 D:A
# 292                                General Asim Gunduz
# 293                                     23 High Street
# 294                                    St James Street
#
#                           City PostalCode           Country Code
# 0                         Graz       8020           Austria   AT
# 1                       Vienna       1080           Austria   AT
# 2                       Vienna       1080           Austria   AT
# 3                       Vienna       1020           Austria   AT
# 4                       Vienna       1080           Austria   AT
# 5                      Antwerp       2000           Belgium   BE
# 6                      Antwerp       2018           Belgium   BE
# 7                    Antwerpen       2000           Belgium   BE
# 8                    Antwerpen       2000           Belgium   BE
# 9                     Brussels       1050           Belgium   BE
# 10                    Brussels       1000           Belgium   BE
# 11                    Brussels       1000           Belgium   BE
# 12                   Bruxelles       1000           Belgium   BE
# 13                        Gent       9000           Belgium   BE
# 14                        Gent       9000           Belgium   BE
# 15                     Hasselt       3500           Belgium   BE
# 16                       Liège       4000           Belgium   BE
# 17                       Namur       5000           Belgium   BE
# 18                Sint-Niklaas       9100           Belgium   BE
# 19                    Tongeren       3700           Belgium   BE
# 20                     Plovdiv       4000          Bulgaria   BG
# 231                    Haarlem    2011 LE       Netherlands   NL
# 232                  The Hague    2513 BW       Netherlands   NL
# 233                Skopje 1000       1000   North Macedonia   MK
# 234                    Belfast    BT4 3NT  Northern Ireland   GB
# 235                    Belfast    BT4 3BE  Northern Ireland   GB
# 236                   Grimstad       4877            Norway   NO
# 237                  Trondheim       7011            Norway   NO
# 238                     Gdansk     80-243            Poland   PL
# 239                   Katowice     40-067            Poland   PL
# 240                     Krakow     31-506            Poland   PL
# 241                     Krakow     31-530            Poland   PL
# 242                       Łódź     90-406            Poland   PL
# 243                       Łódź     90-266            Poland   PL
# 244                     Warsaw     01-456            Poland   PL
# 245                     Warsaw     00-157            Poland   PL
# 246                    Wroclaw     50-106            Poland   PL
# 247                    Wroclaw     50-207            Poland   PL
# 248                    Amadora   2720-238          Portugal   PT
# 249                     Lisboa   1600-617          Portugal   PT
# 250              Vila do Conde   4480-002          Portugal   PT
# 251                  Bucharest     010303           Romania   RO
# 252                  Bucharest     021503           Romania   RO
# 253                Cluj-Napoca     400014           Romania   RO
# 254                       Iasi     700505           Romania   RO
# 255                       Iasi     700107           Romania   RO
# 256                   Ploiesti     100331           Romania   RO
# 257                Targu-Mures     540056           Romania   RO
# 258                   Ayrshire    KA7 1JA          Scotland   GB
# 259                  Edinburgh    EH3 9JB          Scotland   GB
# 260                  Edinburgh    EH8 9BX          Scotland   GB
# 261                  Edinburgh    EH3 8BH          Scotland   GB
# 262                    Glasgow     G2 3HW          Scotland   GB
# 263                    Glasgow     G1 3RB          Scotland   GB
# 264                    Glasgow    G41 3YG          Scotland   GB
# 265                    Glasgow    G41 3YG          Scotland   GB
# 266                    Glasgow     G4 0UL          Scotland   GB
# 267                    Glasgow     G2 3AU          Scotland   GB
# 268                    Glasgow     G3 6UR          Scotland   GB
# 269                   Hamilton    ML3 6BU          Scotland   GB
# 270                 Motherwell    ML1 1LY          Scotland   GB
# 271                    Paisley    PA3 2AN          Scotland   GB
# 272                    Paisley    PA3 2AN          Scotland   GB
# 273                      Perth    PH2 8JW          Scotland   GB
# 274                   Stirling    FK8 1JR          Scotland   GB
# 275                   Belgrade      11000            Serbia   RS
# 276                   Novi Sad      21000            Serbia   RS
# 277                  Ljubljana       1000          Slovenia   SI
# 278                  Barcelona      08010             Spain   ES
# 279                    Granada      18011             Spain   ES
# 280                     Lleida      25005             Spain   ES
# 281                     Madrid      28040             Spain   ES
# 282                     Málaga      29003             Spain   ES
# 283                     Málaga      29001             Spain   ES
# 284          Palma De Mallorca      07004             Spain   ES
# 285                   Valencia      46021             Spain   ES
# 286                   Göteborg     411 19            Sweden   SE
# 287                  Stockholm     112 30            Sweden   SE
# 288                     Basel        4053       Switzerland   CH
# 289                  Dübendorf       8600       Switzerland   CH
# 290          Zürich-Altstetten       8048       Switzerland   CH
# 291                     Ankara      06490            Turkey   TR
# 292           Kadikoy/Istanbul      34714            Turkey   TR
# 293                    Cardiff   CF10 1PT             Wales   GB
# 294                    Newport   PO30 1LQ             Wales   GB

# %%
cafe_df.drop(23, axis=0, inplace=True) # A search reveals that 3 Trolls in Bulgaria is permanently closed
cafe_df.loc[42, 'PostalCode'] = 'NR2 1EL'
cafe_df.loc[73, 'PostalCode'] = 'BN1 4JF'
cafe_df.loc[124, 'PostalCode'] = '03000'
cafe_df.loc[211, 'PostalCode'] = 'P75 XW35'
cafe_df.drop(220, axis=0, inplace=True) # This is in fact related to an event called Counters in Pontypridd, Wales, not Italy
cafe_df.loc[223, 'PostalCode'] = 'MD-2012'
cafe_df.loc[230, 'PostalCode'] = '9712 NP'
cafe_df.loc[231, 'PostalCode'] = '2011 LE'
cafe_df.loc[286, 'PostalCode'] = '411 19'
cafe_df.loc[291, 'PostalCode'] = '06490'

cafe_df.loc[7, 'City'] = 'Antwerp'
cafe_df.drop(8, axis=0, inplace=True)
cafe_df.loc[12, 'City'] = 'Brussels'
cafe_df.loc[16, 'Address'] = 'Rue Hors-Château 43'
cafe_df.loc[17, 'Address'] = 'Place Abbé Joseph André 11'
cafe_df.drop(33, axis=0, inplace=True)
cafe_df.loc[38, 'Address'] = 'Rushden Rd' # This is as accurate as Nominatim can get
cafe_df.drop(43, axis=0, inplace=True)
cafe_df.drop(44, axis=0, inplace=True)
cafe_df.loc[48, 'Address'] = '247 High Street'
cafe_df.drop(50, axis=0, inplace=True)
cafe_df.drop(72, axis=0, inplace=True)
cafe_df.loc[73, 'Address'] = '88 London Rd'
cafe_df.drop(74, axis=0, inplace=True)
cafe_df.loc[75, 'Address'] = '' # Needed in order for geopy to obtain geographical data
cafe_df.drop(79, axis=0, inplace=True)
cafe_df.loc[82, 'Address'] = 'Abinger place'
cafe_df.loc[84, 'Address'] = '207 Queensway'
cafe_df.loc[84, 'PostalCode'] = 'MK2 2EB'
cafe_df.loc[86, 'Address'] = '149 Albert Rd'
cafe_df.loc[89, 'Address'] = 'The Brooks Centre'
cafe_df.loc[103, 'Address'] = '19a Pepper Street'
cafe_df.loc[103, 'PostalCode'] = 'ST5 1PR'
cafe_df.loc[104, 'Name'] = 'Nerdy Coffee Co.'
cafe_df.loc[185, 'Address'] = 'Lehener Straße 15'
cafe_df.loc[194, 'Address'] = 'Λογοθετίδη Βασίλη 14'
cafe_df.loc[194, 'City'] = 'Athens'
cafe_df.loc[196, 'PostalCode'] = '65302'
cafe_df.loc[197, 'PostalCode'] = '41221'
cafe_df.loc[198, 'Address'] = 'Δημητριου Ράλλη 4'
cafe_df.loc[200, 'Address'] = 'Γεωργίου Παπανδρέου 27'
cafe_df.loc[200, 'PostalCode'] = '54645'
cafe_df.loc[202, 'Address'] = 'Βασιλίσσης Σοφίας'
cafe_df.loc[205, 'Address'] = 'Ferenc körút 17'
cafe_df.drop(206, axis=0, inplace=True)
cafe_df.loc[207, 'Name'] = 'Pub Game Up!'
cafe_df.loc[211, 'Address'] = '9 High Street'
cafe_df.drop(212, axis=0, inplace=True)
cafe_df.loc[213, 'Address'] = '51 Wellington Quay'
cafe_df.loc[214, 'PostalCode'] = 'D02 FP40'
cafe_df.loc[215, 'PostalCode'] = 'H91 Y90F'
cafe_df.loc[216, 'Address'] = 'Via Giuseppe Toniolo 12'
cafe_df.loc[223, 'Address'] = 'Strada Alexandr Pușkin 52'
cafe_df.loc[233, 'City'] = 'Skopje'
cafe_df.loc[234, 'Address'] = 'Rosepark, Upper Newtownards Road' # This is as accurate as Nominatim allows
cafe_df.loc[234, 'PostalCode'] = 'BT4 3SB'
cafe_df.loc[235, 'Address'] = 'Holywood Road'
cafe_df.loc[235, 'PostalCode'] = 'BT4 1NT'
cafe_df.loc[238, 'Address'] = 'Dmowskiego 15'
cafe_df.loc[239, 'Address'] = 'Kamienna 7'
cafe_df.loc[248, 'Name'] = 'Ludoclube'
cafe_df.loc[248, 'PostalCode'] = '2720-046'
cafe_df.loc[249, 'Name'] = 'Pow Wow'
cafe_df.loc[249, 'Address'] = 'Rua Professor Fernando da Fonseca 19'
cafe_df.loc[249, 'PostalCode'] = '1600-235'
cafe_df.loc[250, 'Name'] = 'A Jogar é que a gente se entende'
# I don't know how to fix the address for A Jogar; Nominatim can go fuck itself.
cafe_df.loc[252, 'Name'] = 'Snakes & Wizards'
cafe_df.loc[252, 'Address'] = 'Strada Ilarie Chendi 5'
cafe_df.loc[253, 'Address'] = 'Strada Samuil Micu 4'
cafe_df.loc[256, 'Name'] = 'FatCats Board Game Cafe'
cafe_df.loc[256, 'PostalCode'] = '100337'
cafe_df.drop(264, axis=0, inplace=True)
cafe_df.drop(272, axis=0, inplace=True)
cafe_df.loc[280, 'Address'] = "Carrer de l'Alandir 1" # The actual address "Carrer Hospitalers de Sant Joan n.2" is a footpath so doesn't show
cafe_df.loc[282, 'Address'] = 'Av. Manuel Torres 5' # In Nominatim the 'de' given in Google Map returns an error
cafe_df.loc[284, 'Address'] = 'Carrer de Rosselló i Cazador, 7'
cafe_df.loc[292, 'Address'] = 'Nail Bey Sk. No:48/2' # In Nominatim the street name is Nail Bey, not Nailbey as with Google Maps

# %% [markdown]
# In checking `cafe_df` we can see that cafés are not yet group by cities, so let's do that and then reset the indices.

# %%
cafe_df.sort_values(['Country', 'City'], inplace=True)
cafe_df.reset_index(drop=True, inplace=True)
cafe_df.head()
# Out:
#               Name               Address    City PostalCode  Country Code
# 0    Brot & Spiele  Mariahilferstraße 17    Graz       8020  Austria   AT
# 1  Brot und Spiele        Laudongasse 22  Vienna       1080  Austria   AT
# 2       Café Benno         Alser Str. 67  Vienna       1080  Austria   AT
# 3    Café Sperlhof   Große Sperlgasse 41  Vienna       1020  Austria   AT
# 4         SpielBar       Lederergasse 26  Vienna       1080  Austria   AT

# %%
cafe_df.to_csv('cafe_addresses.csv', index=False)

# %%
geolocator = Nominatim(user_agent='bgc_finder')

# %%
cafe_df.values[0]
# Out:
# array(['Brot & Spiele', 'Mariahilferstraße 17', 'Graz', '8020', 'Austria',
#        'AT'], dtype=object)

# %%
ll_list = []

# %%
location = geolocator.geocode('Nailbey Sk. No. 48, 34714, Turkey') 
location.latitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-524-edd04d4c883d> in <module>
#       1 location = geolocator.geocode('Nailbey Sk. No. 48, 34714, Turkey')
# ----> 2 location.latitude
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
def get_ll(row):
    location = geolocator.geocode(f"{row[1]}, {row[3]} {row[2]}, {row[4]}")
    return [location.latitude, location.longitude]

# %%
for row in cafe_df.values:
    ll_dict = dict()
    try:
        ll = get_ll(row)
    except:
        ll = [np.nan, np.nan]
    ll_dict = {'Latitude': ll[0], 'Longitude': ll[1]}
    ll_list.append(ll_dict)

# %%
ll_df = pd.DataFrame(ll_list)
ll_df.head()
# Out:
#     Latitude  Longitude
# 0  47.073272  15.433036
# 1  48.213407  16.349799
# 2  48.215050  16.342587
# 3  48.219658  16.378380
# 4  48.213688  16.348476

# %%
null_idx = ll_df.index[ll_df['Latitude'].isnull()].tolist()
cafe_df.loc[null_idx,:]
# Out:
#                                  Name                           Address  \
# 212            Spellencentrum Agartha                  Legmeerdijk 169a
# 213                        2 Klaveren               De Clercqstraat 136
# 215                    Escaping Breda             Boschstraat 112 -116,
# 216                           Barbaar                Sint Agathaplein 4
# 217                       Bordspelers              Lange Groenendaal 82
# 218                    Purperen Draak          Nieuwe Ebbingestraat 86a
# 220                       Spellenhuis                   Torenstraat 142
# 222                       Jack Straws  Rosepark, Upper Newtownards Road
# 223                 Robins Hobby Cafe                     Holywood Road
# 238  A Jogar é que a gente se entende     Rua Joaquim Maria de Melo 244
#
#               City PostalCode           Country Code
# 212       Aalsmeer    1432 KA       Netherlands   NL
# 213      Amsterdam    1052 NP       Netherlands   NL
# 215          Breda    4811 GK       Netherlands   NL
# 216          Delft    2611 HR       Netherlands   NL
# 217          Gouda    2801 LV       Netherlands   NL
# 218      Groningen    9712 NP       Netherlands   NL
# 220      The Hague    2513 BW       Netherlands   NL
# 222        Belfast    BT4 3SB  Northern Ireland   GB
# 223        Belfast    BT4 1NT  Northern Ireland   GB
# 238  Vila do Conde   4480-002          Portugal   PT

# %%
len(null_idx)
# Out:
# 10

# %%
cafe_df[cafe_df['Country'] == 'Spain']
# Out:
#                          Name                                Address  \
# 265               Kaburi Cafe               Passeig de Sant Joan, 11
# 266      Continental Cafe Pub                       C/ Seminario, 11
# 267                  La Pifia  C/ Hospitalers de Sant Joan n.2 bajos
# 268      Epic Board Game Cafe                     Calle Los Vascos 3
# 269                 Comejuega                Av. de Manuel Torres, 5
# 270  Play Planet Coffe & Shop            Calle San Lorenzo Street 18
# 271              GTS Mallorca           Carrer Rosselló i Caçador, 7
# 272           Bruixes i Fades              Carrer de Rubén Darío, 18
#
#                   City PostalCode Country Code
# 265          Barcelona      08010   Spain   ES
# 266            Granada      18011   Spain   ES
# 267             Lleida      25005   Spain   ES
# 268             Madrid      28040   Spain   ES
# 269             Málaga      29003   Spain   ES
# 270             Málaga      29001   Spain   ES
# 271  Palma De Mallorca      07004   Spain   ES
# 272           Valencia      46021   Spain   ES
