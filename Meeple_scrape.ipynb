# %%
import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup
from pykml import parser
import re
import pgeocode

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
with open('Worldwide_Board_Game_Cafe_List.kml','r') as f:
    doc = parser.parse(f).getroot()

# %%
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_Europe'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'lxml')
table = soup.find_all('table', attrs={'class':'wikitable'})[1]
eu_countries = [td.a.text for td in table.find_all('td')[2::7]]

# %%
eu_countries.remove('United Kingdom')
eu_countries.extend(['England', 'Scotland', 'Wales', 'Northern Ireland'])
eu_countries.sort()

# %%
eu_countries
# Out:
# ['Albania',
#  'Andorra',
#  'Armenia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'England',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Kazakhstan',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Moldova',
#  'Monaco',
#  'Montenegro',
#  'Netherlands',
#  'North Macedonia',
#  'Northern Ireland',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'San Marino',
#  'Scotland',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'Ukraine',
#  'Vatican City',
#  'Wales']

# %%
cafe_list = []

# %%
for e in doc.Document.findall('.//{http://www.opengis.net/kml/2.2}Placemark'):
    cafe_dict = dict()
    if e.ExtendedData.Data[5].value in eu_countries:
        cafe_dict = { 
            'Name': e.name.text,
            'City': e.ExtendedData.Data[2].value.text,
            'PostalCode': e.ExtendedData.Data[4].value.text,
            'Country': e.ExtendedData.Data[5].value.text
                    }
        cafe_list.append(cafe_dict)

# %%
for item in cafe_list:
    if item['Country'] == 'Czech Republic':
        item['Country'] = 'Czechia'

# %%
cafe_df = pd.DataFrame(cafe_list)
cafe_df.head(10)
# Out:
#                          Name       City PostalCode  Country
# 0               Brot & Spiele       Graz       8020  Austria
# 1             Brot und Spiele     Vienna       1080  Austria
# 2                  Café Benno     Vienna       1080  Austria
# 3               Café Sperlhof     Vienna       1020  Austria
# 4                    SpielBar     Vienna       1080  Austria
# 5  The Playground (Hoofdkerk)    Antwerp       2000  Belgium
# 6    The Playground (Station)    Antwerp       2018  Belgium
# 7           Outpost Antwerpen  Antwerpen       2000  Belgium
# 8              The Playground  Antwerpen       2000  Belgium
# 9            La Luck Brussels   Brussels       1050  Belgium

# %%
gn_url = 'http://www.geonames.org/countries/'
gn_response = requests.get(gn_url)
gn_soup = BeautifulSoup(gn_response.content, 'lxml')

# %%
gn_table = gn_soup.find_all('tr')[2:]
code_list = []
for tr in gn_table:
    code_dict = dict()
    td = tr.find_all('td')
    if td[-1].text in ['EU', 'AS']: # We include AS because GeoNames includes Turkey within Asia
        code_dict = {
            'Country': td[4].text,
            'Code': td[0].text
                    }
        code_list.append(code_dict)

# %%
code_df = pd.DataFrame(code_list)

# %%
uk_countries = [{'Country': 'England', 'Code': 'GB'}, 
                {'Country': 'Scotland', 'Code': 'GB'}, 
                {'Country': 'Wales', 'Code': 'GB'}, 
                {'Country': 'Northern Ireland', 'Code': 'GB'}]

# %%
code_df = pd.concat([code_df, pd.DataFrame(uk_countries)])
code_df.set_index('Country', inplace=True)
code_df.drop('United Kingdom', axis=0, inplace=True)
code_df.sort_index()
# Out:
#                                Code
# Country
# Afghanistan                      AF
# Albania                          AL
# Andorra                          AD
# Armenia                          AM
# Austria                          AT
# Azerbaijan                       AZ
# Bahrain                          BH
# Bangladesh                       BD
# Belarus                          BY
# Belgium                          BE
# Bhutan                           BT
# Bosnia and Herzegovina           BA
# British Indian Ocean Territory   IO
# Brunei                           BN
# Bulgaria                         BG
# Cambodia                         KH
# China                            CN
# Cocos [Keeling] Islands          CC
# Croatia                          HR
# Cyprus                           CY
# Czechia                          CZ
# Denmark                          DK
# England                          GB
# Estonia                          EE
# Faroe Islands                    FO
# Finland                          FI
# France                           FR
# Georgia                          GE
# Germany                          DE
# Gibraltar                        GI
# Greece                           GR
# Guernsey                         GG
# Hong Kong                        HK
# Hungary                          HU
# Iceland                          IS
# India                            IN
# Indonesia                        ID
# Iran                             IR
# Iraq                             IQ
# Ireland                          IE
# Isle of Man                      IM
# Israel                           IL
# Italy                            IT
# Japan                            JP
# Jersey                           JE
# Jordan                           JO
# Kazakhstan                       KZ
# Kosovo                           XK
# Kuwait                           KW
# Kyrgyzstan                       KG
# Laos                             LA
# Latvia                           LV
# Lebanon                          LB
# Liechtenstein                    LI
# Lithuania                        LT
# Luxembourg                       LU
# Macao                            MO
# Malaysia                         MY
# Maldives                         MV
# Malta                            MT
# Moldova                          MD
# Monaco                           MC
# Mongolia                         MN
# Montenegro                       ME
# Myanmar                          MM
# Nepal                            NP
# Netherlands                      NL
# North Korea                      KP
# North Macedonia                  MK
# Northern Ireland                 GB
# Norway                           NO
# Oman                             OM
# Pakistan                         PK
# Palestine                        PS
# Philippines                      PH
# Poland                           PL
# Portugal                         PT
# Qatar                            QA
# Romania                          RO
# Russia                           RU
# San Marino                       SM
# Saudi Arabia                     SA
# Scotland                         GB
# Serbia                           RS
# Serbia and Montenegro            CS
# Singapore                        SG
# Slovakia                         SK
# Slovenia                         SI
# South Korea                      KR
# Spain                            ES
# Sri Lanka                        LK
# Svalbard and Jan Mayen           SJ
# Sweden                           SE
# Switzerland                      CH
# Syria                            SY
# Taiwan                           TW
# Tajikistan                       TJ
# Thailand                         TH
# Turkey                           TR
# Turkmenistan                     TM
# Ukraine                          UA
# United Arab Emirates             AE
# Uzbekistan                       UZ
# Vatican City                     VA
# Vietnam                          VN
# Wales                            GB
# Yemen                            YE
# Åland                            AX

# %%
cafe_df = cafe_df.merge(code_df, how='left', on='Country')
cafe_df.head(10)
# Out:
#                          Name       City PostalCode  Country Code
# 0               Brot & Spiele       Graz       8020  Austria   AT
# 1             Brot und Spiele     Vienna       1080  Austria   AT
# 2                  Café Benno     Vienna       1080  Austria   AT
# 3               Café Sperlhof     Vienna       1020  Austria   AT
# 4                    SpielBar     Vienna       1080  Austria   AT
# 5  The Playground (Hoofdkerk)    Antwerp       2000  Belgium   BE
# 6    The Playground (Station)    Antwerp       2018  Belgium   BE
# 7           Outpost Antwerpen  Antwerpen       2000  Belgium   BE
# 8              The Playground  Antwerpen       2000  Belgium   BE
# 9            La Luck Brussels   Brussels       1050  Belgium   BE

# %%
def get_coords(row):
    geo = pgeocode.Nominatim(row[-1])
    coords = geo.query_postal_code(row[2])
    return [coords.latitude, coords.longitude]

# %%
coord_list = []

# %%
for row in cafe_df.values:
    coord_dict = dict()
    try:
        ll = get_coords(row)
    except:
        ll = [np.nan, np.nan]
    coord_dict = {
        'Latitude': ll[0], 
        'Longitude': ll[1]         
                 }
    coord_list.append(coord_dict)

# %%
coord_df = pd.DataFrame(coord_list)
coord_df.head(10)
# Out:
#    Latitude  Longitude
# 0   47.0232    15.5337
# 1   48.2167    16.3500
# 2   48.2167    16.3500
# 3   48.2167    16.4000
# 4   48.2167    16.3500
# 5   51.2199     4.4035
# 6   51.2199     4.4035
# 7   51.2199     4.4035
# 8   51.2199     4.4035
# 9   50.8333     4.3667

# %% [markdown]
# Let's check to see if there are any cafés that could not provide coordinates.

# %%
null_idx = coord_df.index[coord_df['Latitude'].isnull()].tolist()
null_cafes = cafe_df.iloc[null_idx]
null_cafes
# Out:
#                          Name          City      PostalCode      Country Code
# 23                   3 Trolls         Sofia  1505 Oborishte     Bulgaria   BG
# 42            The Games Table      Norwich          NR311JF      England   GB
# 73                Dice Saloon      Brighton          BN14GY      England   GB
# 124            Game of trolls       Moulins            3000       France   FR
# 192                 Playhouse        Athens          106 81       Greece   GR
# 193               Κάισσα Cafe        Athens           11527       Greece   GR
# 194                    Playce        Athina          115 24       Greece   GR
# 195                 Playhouse      Ioannina          453 33       Greece   GR
# 196                 Playhouse        Kavala          652 01       Greece   GR
# 197                 Playhouse        Larisa          412 22       Greece   GR
# 198          This HOUSE RULES       Marousi          151 24       Greece   GR
# 199                 Playhouse         Patra          262 21       Greece   GR
# 200              Back 2 Games  Thessaloniki           54645       Greece   GR
# 201         Harry's Spot Cafe  Thessaloniki           54621       Greece   GR
# 202                 Playhouse        Xanthi          671 00       Greece   GR
# 211                  Tabletop          Cork             021      Ireland   IE
# 220                  Counters    Pontypridd        CF37 4TR        Italy   IT
# 223           Brainstorm Cafe      Chisinau            0000      Moldova   MD
# 224    Spellencentrum Agartha      Aalsmeer         1432 KA  Netherlands   NL
# 225                2 Klaveren     Amsterdam         1052 NP  Netherlands   NL
# 226          Friends and Foes     Amsterdam         1073 NA  Netherlands   NL
# 227            Escaping Breda         Breda         4811 GK  Netherlands   NL
# 228                   Barbaar         Delft         2611 HR  Netherlands   NL
# 229               Bordspelers         Gouda         2801 LV  Netherlands   NL
# 231             The Boardroom       Haarlem          2011LE  Netherlands   NL
# 232               Spellenhuis     The Hague         2513 BW  Netherlands   NL
# 275                     Astal      Belgrade           11000       Serbia   RS
# 276             Gaming Centar      Novi Sad           21000       Serbia   RS
# 286               Café Sirius      Göteborg           41119       Sweden   SE
# 291  Da Vinci Board Game Cafe        Ankara            6490       Turkey   TR

# %% [markdown]
# Well, that's a number of missing data pieces. On a hunch, let's first count the number of cafés per country in both `cafe_df` and `null_cafes`.

# %%
cafe_df.groupby('Country').count()
# Out:
#                   Name  City  PostalCode  Code
# Country
# Austria              5     5           5     5
# Belgium             15    15          15    15
# Bulgaria             4     4           4     4
# Czechia              3     3           3     3
# Denmark             11    11          11    11
# England             78    78          78    78
# Finland              2     2           2     2
# France              57    57          57    57
# Germany             17    17          17    17
# Greece              11    11          11    11
# Hungary              7     7           7     7
# Iceland              1     1           1     1
# Ireland              5     5           5     5
# Italy                7     7           7     7
# Moldova              1     1           1     1
# Netherlands          9     9           9     9
# North Macedonia      1     1           1     1
# Northern Ireland     2     2           2     2
# Norway               2     2           2     2
# Poland              10    10          10    10
# Portugal             3     3           3     3
# Romania              7     7           7     7
# Scotland            17    17          17    17
# Serbia               2     2           2     2
# Slovenia             1     1           1     1
# Spain                8     8           8     8
# Sweden               2     2           2     2
# Switzerland          3     3           3     3
# Turkey               2     2           2     2
# Wales                2     2           2     2

# %%
null_cafes.groupby('Country').count()
# Out:
#              Name  City  PostalCode  Code
# Country
# Bulgaria        1     1           1     1
# England         2     2           2     2
# France          1     1           1     1
# Greece         11    11          11    11
# Ireland         1     1           1     1
# Italy           1     1           1     1
# Moldova         1     1           1     1
# Netherlands     8     8           8     8
# Serbia          2     2           2     2
# Sweden          1     1           1     1
# Turkey          1     1           1     1

# %% [markdown]
# By comparing these numbers, we can see that every café in Greece, Moldova and Serbia are missing, which suggests that `pgeocode` does not contain information for these countries (and a check of the [github page](https://github.com/symerio/pgeocode) for `pgeocode` confirms this). This will require utilising a different source for the information.
# Otherwise, the postal codes for the remaining entries of `null_cafes` must contain errors and need to be manually changed.

# %%
cafe_df.drop(23, axis=0, inplace=True) # A search reveals that 3 Trolls in Bulgaria is permanently closed
cafe_df.loc[42, 'PostalCode'] = 'NR2 1EL'
cafe_df.loc[73, 'PostalCode'] = 'BN1 4JF'
cafe_df.loc[124, 'PostalCode'] = '03000'
cafe_df.loc[211, 'PostalCode'] = 'P75 AE30'
cafe_df.drop(220, axis=0, inplace=True) # This is in fact related to an event called Counters in Pontypridd, Wales, not Italy
cafe_df.loc[223, 'PostalCode'] = 'MD-2012'
cafe_df.loc[230, 'PostalCode'] = '9712 NP'
cafe_df.loc[231, 'PostalCode'] = '2011 LE'
cafe_df.loc[286, 'PostalCode'] = '411 19'
cafe_df.loc[291, 'PostalCode'] = '06490'

# %% [markdown]
# So, what is next to sort out is a) making sure we can obtain the coordinates for Greece, Moldova and Serbia (and Netherlands); and b) remove any duplicate entries within `cafe_df`.

# %% [markdown]
# Starting with the duplicates...
#
# * Antwerpen is the Dutch name for Antwerp, and so 'The Playground' in Antwerpen is duplicate of one of the two 'The Playground's already listed within the city.
#
#
# In addition, we need to change the city names to match---e.g. the above issue with Antwerpen vs. Antwerp, and Bruxelles and Brussels---in order to later group things by city.

# %%
cafe_df.loc[7, 'City'] = 'Antwerp'
cafe_df.drop(8, axis=0, inplace=True)
cafe_df.loc[12, 'City'] = 'Brussels'
cafe_df.drop(33, axis=0, inplace=True)
cafe_df.drop(44, axis=0, inplace=True)
cafe_df.drop(50, axis=0, inplace=True)
cafe_df.drop(74, axis=0, inplace=True)
cafe_df.drop(79, axis=0, inplace=True)
cafe_df.loc[104, 'Name'] = 'Nerdy Coffee Co.'
cafe_df.loc[194, 'City'] = 'Athens'
cafe_df.drop(206, axis=0, inplace=True)
cafe_df.loc[207, 'Name'] = 'Pub Game Up!'
cafe_df.drop(212, axis=0, inplace=True)
cafe_df.drop(264, axis=0, inplace=True)
cafe_df.drop(272, axis=0, inplace=True)
# Out:
#                                              Name                       City  \
# 0                                   Brot & Spiele                       Graz
# 1                                 Brot und Spiele                     Vienna
# 2                                      Café Benno                     Vienna
# 3                                   Café Sperlhof                     Vienna
# 4                                        SpielBar                     Vienna
# 5                      The Playground (Hoofdkerk)                    Antwerp
# 6                        The Playground (Station)                    Antwerp
# 7                               Outpost Antwerpen                    Antwerp
# 9                                La Luck Brussels                   Brussels
# 10                          La Table Food & Games                   Brussels
# 11                               Outpost Brussels                   Brussels
# 12                               Kings and Queens                   Brussels
# 13                             OutPost Gamecenter                       Gent
# 14              World's End Comics & Games Center                       Gent
# 15                                        Oberonn                    Hasselt
# 16                                       Yam-toto                      Liège
# 17                         Aux 3D Board Game Cafe                      Namur
# 18                                Brood en Spelen               Sint-Niklaas
# 19                                        De Ezel                   Tongeren
# 20                                  Meeple People                    Plovdiv
# 21                                   Offline Café                    Plovdiv
# 22                                BoardGames Ruse                       Ruse
# 24                              Mystica TEA & PUB                       Brno
# 25                            A Maze in Tchaiovna                     Prague
# 26                         Bohemia Boards & Brews                     Prague
# 27                          Aalborg Brætspilscafé                    Aalborg
# 28                                 Dice 'n Drinks                    Aalborg
# 29                Aarhus Brtspilscafe Fredensgade                   Aarhus C
# 30                 Aarhus Brtspilscafe Vestergade                   Aarhus C
# 31                                   Bastard Cafe                 Copenhagen
# 32                  Social Corner Board Game Cafe                 Copenhagen
# 34                                        Topdeck                   Hillerød
# 35                                   Cafe Firefly                    Kolding
# 36                                   Papas Papbar                     Odense
# 37                                         Æ Bræt                 Sønderborg
# 38                             Ready Steady Roll                     Bedford
# 39                          Counter Culture Games                 Chelmsford
# 40                Slice and Dice (monthly pop up)                    Norwich
# 41                           Zatu Board Game Café                    Norwich
# 42                                The Games Table                   Norwich
# 43                              Ready Steady Roll                 Sharnbrook
# 45                            d20 Board Game Cafe                    Watford
# 46                                    Bean Gaming                  Leicester
# 47                                          Quest                  Leicester
# 48                          Red Panda Gaming Cafe                    Lincoln
# 49                        Geek Retreat Nottingham                 Nottingham
# 51                                  Ludorati Café                 Nottingham
# 52                                   The Dice Cup                 Nottingham
# 53                      Ludoquist Board Game Cafe                    Croydon
# 54                                  Bad Moon Cafe                     London
# 55           Draughts - Board Game Café - Hackney                     London
# 56          Draughts - Board Game Café - Waterloo                     London
# 57                                The Library Pot                   Richmond
# 58                            Loading Bar Dalston            Stoke Newington
# 59                                       tea@HART                 Hartlepool
# 60                                  Fire and Dice             Middlesbrough
# 61                                    Meeple Perk        Newcastle upon Tyne
# 62                         Geek Retreat Newcastle        Newcastle-upon-Tyne
# 63                                    Cherry Moon                     Bolton
# 64                                   Slice & Dice                     Bolton
# 65                        Critical Hit Games Cafe                  Liverpool
# 66                                 Sugar and Dice                  Liverpool
# 67                                     Tiny Ricks                  Liverpool
# 284                                  GTS Mallorca          Palma De Mallorca
# 285                               Bruixes i Fades                   Valencia
# 286                                   Café Sirius                   Göteborg
# 287                               Dice Cafe STHLM                  Stockholm
# 288                                       ManaBar                     Basel
# 289                                   Well Played                  Dübendorf
# 290                                    DuBischDra          Zürich-Altstetten
# 291                      Da Vinci Board Game Cafe                     Ankara
# 292                              Goblin Oyun Cafe           Kadikoy/Istanbul
# 293                             Chance & Counters                    Cardiff
# 294                          Board, Isle of Wight                    Newport
#
#     PostalCode           Country Code
# 0         8020           Austria   AT
# 1         1080           Austria   AT
# 2         1080           Austria   AT
# 3         1020           Austria   AT
# 4         1080           Austria   AT
# 5         2000           Belgium   BE
# 6         2018           Belgium   BE
# 7         2000           Belgium   BE
# 9         1050           Belgium   BE
# 10        1000           Belgium   BE
# 11        1000           Belgium   BE
# 12        1000           Belgium   BE
# 13        9000           Belgium   BE
# 14        9000           Belgium   BE
# 15        3500           Belgium   BE
# 16        4000           Belgium   BE
# 17        5000           Belgium   BE
# 18        9100           Belgium   BE
# 19        3700           Belgium   BE
# 20        4000          Bulgaria   BG
# 21        4000          Bulgaria   BG
# 22        7000          Bulgaria   BG
# 24      612 00           Czechia   CZ
# 25      160 00           Czechia   CZ
# 26      101 00           Czechia   CZ
# 27        9000           Denmark   DK
# 28        9000           Denmark   DK
# 29        8000           Denmark   DK
# 30        8000           Denmark   DK
# 31        1466           Denmark   DK
# 32        1171           Denmark   DK
# 34        3400           Denmark   DK
# 35        6000           Denmark   DK
# 36        5000           Denmark   DK
# 37        6400           Denmark   DK
# 38    MK44 1ND           England   GB
# 39     CM2 0DG           England   GB
# 40     NR3 1LJ           England   GB
# 41     NR5 9HA           England   GB
# 42     NR2 1EL           England   GB
# 43    MK44 1ND           England   GB
# 45    WD17 2QN           England   GB
# 46     LE1 5ET           England   GB
# 47     LE1 6SL           England   GB
# 48     LN2 1HW           England   GB
# 49     NG1 2HN           England   GB
# 51     NG1 6BJ           England   GB
# 52     NG1 3GY           England   GB
# 53     CR0 1QE           England   GB
# 54     SE1 4GZ           England   GB
# 55      E8 2JS           England   GB
# 56     SE1 7NN           England   GB
# 57     TW9 2PQ           England   GB
# 58     N16 8BX           England   GB
# 59    TS26 9DE           England   GB
# 60     TS1 4AF           England   GB
# 61     NE1 5PZ           England   GB
# 62     NE1 5JG           England   GB
# 63     BL1 2EH           England   GB
# 64     BL1 1HL           England   GB
# 65      L3 8HE           England   GB
# 66      L1 8DN           England   GB
# 67     L15 3JL           England   GB
# 68      M1 1EL           England   GB
# 69     CW9 5DW           England   GB
# 70    CH47 3BD           England   GB
# 71    RG21 7NT           England   GB
# 72     BN2 1ET           England   GB
# 73     BN1 4JF           England   GB
# 75     BN2 1ET           England   GB
# 76     BR1 1TS           England   GB
# 77    PO19 1NB           England   GB
# 78     CO1 2PQ           England   GB
# 80    DA11 0BJ           England   GB
# 81     GU1 4AP           England   GB
# 82     BN7 2QA           England   GB
# 83     CT9 1DX           England   GB
# 84     MK2 2EE           England   GB
# 196     652 01            Greece   GR
# 197     412 22            Greece   GR
# 198     151 24            Greece   GR
# 199     262 21            Greece   GR
# 200      54645            Greece   GR
# 201      54621            Greece   GR
# 202     671 00            Greece   GR
# 203       1111           Hungary   HU
# 204       1065           Hungary   HU
# 205       1094           Hungary   HU
# 207       1066           Hungary   HU
# 208       1066           Hungary   HU
# 209       4024           Hungary   HU
# 210        108           Iceland   IS
# 211   P75 AE30           Ireland   IE
# 213   D02 NH04           Ireland   IE
# 214   D02 RF34           Ireland   IE
# 215   H91 KC79           Ireland   IE
# 216      54033             Italy   IT
# 217      20147             Italy   IT
# 218      20900             Italy   IT
# 219      56124             Italy   IT
# 221      00185             Italy   IT
# 222      10126             Italy   IT
# 223    MD-2012           Moldova   MD
# 224    1432 KA       Netherlands   NL
# 225    1052 NP       Netherlands   NL
# 226    1073 NA       Netherlands   NL
# 227    4811 GK       Netherlands   NL
# 228    2611 HR       Netherlands   NL
# 229    2801 LV       Netherlands   NL
# 230    9712 NP       Netherlands   NL
# 231    2011 LE       Netherlands   NL
# 232    2513 BW       Netherlands   NL
# 233       1000   North Macedonia   MK
# 234    BT4 3NT  Northern Ireland   GB
# 235    BT4 3BE  Northern Ireland   GB
# 236       4877            Norway   NO
# 237       7011            Norway   NO
# 238     80-243            Poland   PL
# 239     40-067            Poland   PL
# 240     31-506            Poland   PL
# 241     31-530            Poland   PL
# 242     90-406            Poland   PL
# 243     90-266            Poland   PL
# 244     01-456            Poland   PL
# 245     00-157            Poland   PL
# 246     50-106            Poland   PL
# 247     50-207            Poland   PL
# 248   2720-238          Portugal   PT
# 249   1600-617          Portugal   PT
# 250   4480-002          Portugal   PT
# 251     010303           Romania   RO
# 252     021503           Romania   RO
# 253     400014           Romania   RO
# 254     700505           Romania   RO
# 255     700107           Romania   RO
# 256     100331           Romania   RO
# 257     540056           Romania   RO
# 258    KA7 1JA          Scotland   GB
# 259    EH3 9JB          Scotland   GB
# 260    EH8 9BX          Scotland   GB
# 261    EH3 8BH          Scotland   GB
# 262     G2 3HW          Scotland   GB
# 263     G1 3RB          Scotland   GB
# 265    G41 3YG          Scotland   GB
# 266     G4 0UL          Scotland   GB
# 267     G2 3AU          Scotland   GB
# 268     G3 6UR          Scotland   GB
# 269    ML3 6BU          Scotland   GB
# 270    ML1 1LY          Scotland   GB
# 271    PA3 2AN          Scotland   GB
# 273    PH2 8JW          Scotland   GB
# 274    FK8 1JR          Scotland   GB
# 275      11000            Serbia   RS
# 276      21000            Serbia   RS
# 277       1000          Slovenia   SI
# 278      08010             Spain   ES
# 279      18011             Spain   ES
# 280      25005             Spain   ES
# 281      28040             Spain   ES
# 282      29003             Spain   ES
# 283      29001             Spain   ES
# 284      07004             Spain   ES
# 285      46021             Spain   ES
# 286     411 19            Sweden   SE
# 287     112 30            Sweden   SE
# 288       4053       Switzerland   CH
# 289       8600       Switzerland   CH
# 290       8048       Switzerland   CH
# 291      06490            Turkey   TR
# 292      34714            Turkey   TR
# 293   CF10 1PT             Wales   GB
# 294   PO30 1LQ             Wales   GB

# %% [markdown]
# In checking `cafe_df` we can see that cafés are not yet group by cities, so let's do that and then reset the indices.

# %%
cafe_df.sort_values(['Country', 'City'], inplace=True)
cafe_df.reset_index(drop=True, inplace=True)
cafe_df
# Out:
#                                              Name                       City  \
# 0                                   Brot & Spiele                       Graz
# 1                                 Brot und Spiele                     Vienna
# 2                                      Café Benno                     Vienna
# 3                                   Café Sperlhof                     Vienna
# 4                                        SpielBar                     Vienna
# 5                      The Playground (Hoofdkerk)                    Antwerp
# 6                        The Playground (Station)                    Antwerp
# 7                               Outpost Antwerpen                    Antwerp
# 8                                La Luck Brussels                   Brussels
# 9                           La Table Food & Games                   Brussels
# 10                               Outpost Brussels                   Brussels
# 11                               Kings and Queens                   Brussels
# 12                             OutPost Gamecenter                       Gent
# 13              World's End Comics & Games Center                       Gent
# 14                                        Oberonn                    Hasselt
# 15                                       Yam-toto                      Liège
# 16                         Aux 3D Board Game Cafe                      Namur
# 17                                Brood en Spelen               Sint-Niklaas
# 18                                        De Ezel                   Tongeren
# 19                                  Meeple People                    Plovdiv
# 20                                   Offline Café                    Plovdiv
# 21                                BoardGames Ruse                       Ruse
# 22                              Mystica TEA & PUB                       Brno
# 23                            A Maze in Tchaiovna                     Prague
# 24                         Bohemia Boards & Brews                     Prague
# 25                          Aalborg Brætspilscafé                    Aalborg
# 26                                 Dice 'n Drinks                    Aalborg
# 27                Aarhus Brtspilscafe Fredensgade                   Aarhus C
# 28                 Aarhus Brtspilscafe Vestergade                   Aarhus C
# 29                                   Bastard Cafe                 Copenhagen
# 30                  Social Corner Board Game Cafe                 Copenhagen
# 31                                        Topdeck                   Hillerød
# 32                                   Cafe Firefly                    Kolding
# 33                                   Papas Papbar                     Odense
# 34                                         Æ Bræt                 Sønderborg
# 35                                 The Gaming Den                Basingstoke
# 36                                Thirsty Meeples                       Bath
# 37                             Ready Steady Roll                     Bedford
# 38                              Chance & Counters                 Birmingham
# 39                        Geek Retreat Birmingham                 Birmingham
# 40                                  Meeple Mayhem                 Birmingham
# 41                                 Sliced N Diced                 Birmingham
# 42                 Snax & Ladders Board Game Cafe                 Birmingham
# 43                                    Cherry Moon                     Bolton
# 44                                   Slice & Dice                     Bolton
# 45                          Geek Retreat Bradford                   Bradford
# 46                                 c:\ Side Quest                   Brighton
# 47                                    Dice Saloon                   Brighton
# 48                           Loading Bar Brighton                   Brighton
# 49                              Chance & Counters                    Bristol
# 50                  Replay Bristol Board Game Bar                    Bristol
# 51                                   Paradice BGC                    Bromley
# 52                          Counter Culture Games                 Chelmsford
# 53                          Comics Games & Coffee                 Chichester
# 54                                 Dice & a Slice                 Colchester
# 55                      Ludoquist Board Game Cafe                    Croydon
# 56                            Bake, Battle & Roll                  Doncaster
# 57                                          Board                     Exeter
# 58                               The Mug & Meeple                  Gravesend
# 59                                  Unplug & Play                  Guildford
# 60                                       tea@HART                 Hartlepool
# 61                                      IQ Gaming               Huddersfield
# 62                            The People's Meeple               Huddersfield
# 63                                 The Board Room                       Hull
# 64                                 Dice & a Slice                 Ilfracombe
# 272                                  GTS Mallorca          Palma De Mallorca
# 273                               Bruixes i Fades                   Valencia
# 274                                   Café Sirius                   Göteborg
# 275                               Dice Cafe STHLM                  Stockholm
# 276                                       ManaBar                     Basel
# 277                                   Well Played                  Dübendorf
# 278                                    DuBischDra          Zürich-Altstetten
# 279                      Da Vinci Board Game Cafe                     Ankara
# 280                              Goblin Oyun Cafe           Kadikoy/Istanbul
# 281                             Chance & Counters                    Cardiff
# 282                          Board, Isle of Wight                    Newport
#
#     PostalCode           Country Code
# 0         8020           Austria   AT
# 1         1080           Austria   AT
# 2         1080           Austria   AT
# 3         1020           Austria   AT
# 4         1080           Austria   AT
# 5         2000           Belgium   BE
# 6         2018           Belgium   BE
# 7         2000           Belgium   BE
# 8         1050           Belgium   BE
# 9         1000           Belgium   BE
# 10        1000           Belgium   BE
# 11        1000           Belgium   BE
# 12        9000           Belgium   BE
# 13        9000           Belgium   BE
# 14        3500           Belgium   BE
# 15        4000           Belgium   BE
# 16        5000           Belgium   BE
# 17        9100           Belgium   BE
# 18        3700           Belgium   BE
# 19        4000          Bulgaria   BG
# 20        4000          Bulgaria   BG
# 21        7000          Bulgaria   BG
# 22      612 00           Czechia   CZ
# 23      160 00           Czechia   CZ
# 24      101 00           Czechia   CZ
# 25        9000           Denmark   DK
# 26        9000           Denmark   DK
# 27        8000           Denmark   DK
# 28        8000           Denmark   DK
# 29        1466           Denmark   DK
# 30        1171           Denmark   DK
# 31        3400           Denmark   DK
# 32        6000           Denmark   DK
# 33        5000           Denmark   DK
# 34        6400           Denmark   DK
# 35    RG21 7NT           England   GB
# 36     BA1 2NT           England   GB
# 37    MK44 1ND           England   GB
# 38      B9 4AA           England   GB
# 39      B4 7LA           England   GB
# 40     b16 9AG           England   GB
# 41     B29 6HW           England   GB
# 42     B30 1JB           England   GB
# 43     BL1 2EH           England   GB
# 44     BL1 1HL           England   GB
# 45     BD1 1PU           England   GB
# 46     BN2 1ET           England   GB
# 47     BN1 4JF           England   GB
# 48     BN2 1ET           England   GB
# 49     BS1 5BS           England   GB
# 50     BS6 5RB           England   GB
# 51     BR1 1TS           England   GB
# 52     CM2 0DG           England   GB
# 53    PO19 1NB           England   GB
# 54     CO1 2PQ           England   GB
# 55     CR0 1QE           England   GB
# 56     DN1 3LW           England   GB
# 57     EX1 1EQ           England   GB
# 58    DA11 0BJ           England   GB
# 59     GU1 4AP           England   GB
# 60    TS26 9DE           England   GB
# 61     HD1 1DR           England   GB
# 62     HD1 2tw           England   GB
# 63     HU5 2ES           England   GB
# 64    EX34 9NH           England   GB
# 65    CV32 4NX           England   GB
# 66     LS1 6DX           England   GB
# 67     LE1 5ET           England   GB
# 68     LE1 6SL           England   GB
# 69     BN7 2QA           England   GB
# 70     LN2 1HW           England   GB
# 71      L3 8HE           England   GB
# 72      L1 8DN           England   GB
# 73     L15 3JL           England   GB
# 74     SE1 4GZ           England   GB
# 75      E8 2JS           England   GB
# 76     SE1 7NN           England   GB
# 77    WR14 4HU           England   GB
# 78      M1 1EL           England   GB
# 190     412 22            Greece   GR
# 191     151 24            Greece   GR
# 192     262 21            Greece   GR
# 193      54645            Greece   GR
# 194      54621            Greece   GR
# 195     671 00            Greece   GR
# 196       1111           Hungary   HU
# 197       1065           Hungary   HU
# 198       1094           Hungary   HU
# 199       1066           Hungary   HU
# 200       1066           Hungary   HU
# 201       4024           Hungary   HU
# 202        108           Iceland   IS
# 203   P75 AE30           Ireland   IE
# 204   D02 NH04           Ireland   IE
# 205   D02 RF34           Ireland   IE
# 206   H91 KC79           Ireland   IE
# 207      54033             Italy   IT
# 208      20147             Italy   IT
# 209      20900             Italy   IT
# 210      56124             Italy   IT
# 211      00185             Italy   IT
# 212      10126             Italy   IT
# 213    MD-2012           Moldova   MD
# 214    1432 KA       Netherlands   NL
# 215    1052 NP       Netherlands   NL
# 216    1073 NA       Netherlands   NL
# 217    4811 GK       Netherlands   NL
# 218    2611 HR       Netherlands   NL
# 219    2801 LV       Netherlands   NL
# 220    9712 NP       Netherlands   NL
# 221    2011 LE       Netherlands   NL
# 222    2513 BW       Netherlands   NL
# 223       1000   North Macedonia   MK
# 224    BT4 3NT  Northern Ireland   GB
# 225    BT4 3BE  Northern Ireland   GB
# 226       4877            Norway   NO
# 227       7011            Norway   NO
# 228     80-243            Poland   PL
# 229     40-067            Poland   PL
# 230     31-506            Poland   PL
# 231     31-530            Poland   PL
# 232     01-456            Poland   PL
# 233     00-157            Poland   PL
# 234     50-106            Poland   PL
# 235     50-207            Poland   PL
# 236     90-406            Poland   PL
# 237     90-266            Poland   PL
# 238   2720-238          Portugal   PT
# 239   1600-617          Portugal   PT
# 240   4480-002          Portugal   PT
# 241     010303           Romania   RO
# 242     021503           Romania   RO
# 243     400014           Romania   RO
# 244     700505           Romania   RO
# 245     700107           Romania   RO
# 246     100331           Romania   RO
# 247     540056           Romania   RO
# 248    KA7 1JA          Scotland   GB
# 249    EH3 9JB          Scotland   GB
# 250    EH8 9BX          Scotland   GB
# 251    EH3 8BH          Scotland   GB
# 252     G2 3HW          Scotland   GB
# 253     G1 3RB          Scotland   GB
# 254    G41 3YG          Scotland   GB
# 255     G4 0UL          Scotland   GB
# 256     G2 3AU          Scotland   GB
# 257     G3 6UR          Scotland   GB
# 258    ML3 6BU          Scotland   GB
# 259    ML1 1LY          Scotland   GB
# 260    PA3 2AN          Scotland   GB
# 261    PH2 8JW          Scotland   GB
# 262    FK8 1JR          Scotland   GB
# 263      11000            Serbia   RS
# 264      21000            Serbia   RS
# 265       1000          Slovenia   SI
# 266      08010             Spain   ES
# 267      18011             Spain   ES
# 268      25005             Spain   ES
# 269      28040             Spain   ES
# 270      29003             Spain   ES
# 271      29001             Spain   ES
# 272      07004             Spain   ES
# 273      46021             Spain   ES
# 274     411 19            Sweden   SE
# 275     112 30            Sweden   SE
# 276       4053       Switzerland   CH
# 277       8600       Switzerland   CH
# 278       8048       Switzerland   CH
# 279      06490            Turkey   TR
# 280      34714            Turkey   TR
# 281   CF10 1PT             Wales   GB
# 282   PO30 1LQ             Wales   GB
