# %%
import pandas as pd
import numpy as np
import requests
import json
from bs4 import BeautifulSoup
from pykml import parser
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
url = 'https://www.google.com/maps/d/u/1/embed?mid=1UEkafkpKjbEJQzkcwgdtmnYPn4jXQKrw'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')

# %%
soup.find('script', attrs={'nonce':'o22mFVVpMGODzcMj9EoVRQ'})
# Out:
# <script nonce="o22mFVVpMGODzcMj9EoVRQ">
#   function _DumpException(e) {
#     if (window.console) {
#       window.console.error(e.stack);
#     }
#   }
# ...

# %%
headers = {
    'authority': 'www.google.com',
    'x-same-domain': '1',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36',
    'content-type': 'application/x-www-form-urlencoded;charset=UTF-8',
    'accept': '*/*',
    'origin': 'https://www.google.com',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.google.com/maps/d/embed?mid=1UEkafkpKjbEJQzkcwgdtmnYPn4jXQKrw',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
}

params = (
    ('cid', 'mme'),
    ('_reqid', '49062'),
    ('rt', 'j'),
)

data = {
  'f.req': '[58,null,7,null,[730,480]]',
  '': ''
}

response = requests.post('https://www.google.com/maps/d/gen204', headers=headers, params=params, data=data)

# %%
response.content
# Out:
# b')]}\'\n\n[[["f.mt"]\n,["e",2,null,null,41]\n]]'

# %%
with open('Worldwide_Board_Game_Cafe_List.kml','r') as f:
    doc = parser.parse(f).getroot()

# %%
e1 = doc.Document.find('.//{http://www.opengis.net/kml/2.2}Placemark')
e1.ExtendedData.Data[5].value
# Out:
# 'Argentina'

# %%
for e in doc.Document.findall('.//{http://www.opengis.net/kml/2.2}Placemark'):
    print(e.ExtendedData.Data[5].value)
# Out:
# Argentina
# Argentina
# Argentina
# Argentina
# Australia
# Australia
# Australia
# Australia
# Australia
# Australia
# Australia
# Australia
# Australia
# Australia
# Austria
# Austria
# Austria
# Austria
# Austria
# Bahrain
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Belgium
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Brazil
# Bulgaria
# Bulgaria
# Bulgaria
# Bulgaria
# Cambodia
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# Canada
# ...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_Europe'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'lxml')
table = soup.find_all('table', attrs={'class':'wikitable'})[1]
[td.a.text for td in table.find_all('td')[2::7]]
# Out:
# ['Albania',
#  'Andorra',
#  'Armenia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Kazakhstan',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Moldova',
#  'Monaco',
#  'Montenegro',
#  'Netherlands',
#  'North Macedonia',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'San Marino',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'Ukraine',
#  'United Kingdom',
#  'Vatican City']
